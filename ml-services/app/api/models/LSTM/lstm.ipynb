# %%
import os
import numpy as np
import pandas as pd

from sklearn.preprocessing import MinMaxScaler

# %%
ROOT = r"D:\Randome shit\TourX\ml-services\Geolife Trajectories 1.3\Data"

def load_all_geolife(root_path):
    all_data = []

    for user in os.listdir(root_path):
        user_path = os.path.join(root_path, user, "Trajectory")

        if os.path.exists(user_path):

            for file in os.listdir(user_path):
                if file.endswith(".plt"):
                    file_path = os.path.join(user_path, file)

                    df = pd.read_csv(
                        file_path,
                        skiprows=6,
                        header=None,
                        names=["lat","lon","unused","alt","date","date2","time"]
                    )

                    df["user_id"] = user
                    df["trajectory_id"] = file

                    all_data.append(df)

    return pd.concat(all_data, ignore_index=True)

df = load_all_geolife(ROOT)

print("Loaded shape:", df.shape)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 29
#      25                     all_data.append(df)
#      27     return pd.concat(all_data, ignore_index=True)
# ---> 29 df = load_all_geolife(ROOT)
#      31 print("Loaded shape:", df.shape)
#      32 df.head()
#
# Cell In[22], line 15, in load_all_geolife(root_path)
#      12 if file.endswith(".plt"):
#      13     file_path = os.path.join(user_path, file)
# ---> 15     df = pd.read_csv(
#      16         file_path,
#      17         skiprows=6,
#      18         header=None,
#      19         names=["lat","lon","unused","alt","date","date2","time"]
#      20     )
#      22     df["user_id"] = user
#      23     df["trajectory_id"] = file
#
# File d:\Randome shit\TourX\ml-services\venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File d:\Randome shit\TourX\ml-services\venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File d:\Randome shit\TourX\ml-services\venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File d:\Randome shit\TourX\ml-services\venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File d:\Randome shit\TourX\ml-services\venv\Lib\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# File <frozen codecs>:312, in __init__(self, errors)
#
# KeyboardInterrupt:

# %%
# Convert Excel serial to numeric
df["date"] = pd.to_numeric(df["date"], errors="coerce")

# Convert to timestamp
df["timestamp"] = pd.to_datetime(
    df["date"],
    unit="D",
    origin="1899-12-30"
)

# Clean precision noise
df["timestamp"] = df["timestamp"].dt.round("1s")

# Drop bad rows
df = df.dropna(subset=["timestamp"])

# Sort correctly
df = df.sort_values(["user_id", "trajectory_id", "timestamp"])

print("Timestamp fixed")
df.head()
# Out:
# Timestamp fixed
#          lat         lon  unused    alt          date       date2      time  \
# 0  39.984702  116.318417       0  492.0  39744.120185  2008-10-23  02:53:04
# 1  39.984683  116.318450       0  492.0  39744.120255  2008-10-23  02:53:10
# 2  39.984686  116.318417       0  492.0  39744.120313  2008-10-23  02:53:15
# 3  39.984688  116.318385       0  492.0  39744.120370  2008-10-23  02:53:20
# 4  39.984655  116.318263       0  492.0  39744.120428  2008-10-23  02:53:25
#
#   user_id       trajectory_id           timestamp
# 0     000  20081023025304.plt 2008-10-23 02:53:04
# 1     000  20081023025304.plt 2008-10-23 02:53:10
# 2     000  20081023025304.plt 2008-10-23 02:53:15
# 3     000  20081023025304.plt 2008-10-23 02:53:20
# 4     000  20081023025304.plt 2008-10-23 02:53:25

# %%
df["time_gap"] = (
    df.groupby(["user_id","trajectory_id"])["timestamp"]
      .diff()
      .dt.total_seconds()
)

# %%
df["prev_lat"] = df.groupby(["user_id","trajectory_id"])["lat"].shift()
df["prev_lon"] = df.groupby(["user_id","trajectory_id"])["lon"].shift()

# %%
def haversine(lat1, lon1, lat2, lon2):
    R = 6371000  # meters
    phi1 = np.radians(lat1)
    phi2 = np.radians(lat2)
    delta_phi = np.radians(lat2 - lat1)
    delta_lambda = np.radians(lon2 - lon1)

    a = np.sin(delta_phi/2)**2 + \
        np.cos(phi1) * np.cos(phi2) * np.sin(delta_lambda/2)**2

    return 2 * R * np.arcsin(np.sqrt(a))

df["distance_delta"] = haversine(
    df["prev_lat"], df["prev_lon"],
    df["lat"], df["lon"]
)

# %%
df["speed"] = df["distance_delta"] / df["time_gap"]

# %%
df["prev_speed"] = df.groupby(["user_id","trajectory_id"])["speed"].shift()

df["acceleration"] = (
    (df["speed"] - df["prev_speed"]) / df["time_gap"]
)

# %%
def compute_bearing(lat1, lon1, lat2, lon2):
    lat1 = np.radians(lat1)
    lat2 = np.radians(lat2)
    delta_lon = np.radians(lon2 - lon1)

    x = np.sin(delta_lon) * np.cos(lat2)
    y = (
        np.cos(lat1) * np.sin(lat2)
        - np.sin(lat1) * np.cos(lat2) * np.cos(delta_lon)
    )

    bearing = np.degrees(np.arctan2(x, y))
    bearing = (bearing + 360) % 360
    return bearing

df["bearing"] = compute_bearing(
    df["prev_lat"],
    df["prev_lon"],
    df["lat"],
    df["lon"]
)

# %%
df["prev_bearing"] = df.groupby(
    ["user_id","trajectory_id"]
)["bearing"].shift()

df["direction_change"] = abs(df["bearing"] - df["prev_bearing"])

df["direction_change"] = np.minimum(
    df["direction_change"],
    360 - df["direction_change"]
)

# %%
df = df.dropna()

print("After cleaning:", df.shape)
# Out:
# After cleaning: (24213481, 20)

# %%
df.head()
# Out:
#          lat         lon  unused    alt          date       date2      time  \
# 2  39.984686  116.318417       0  492.0  39744.120313  2008-10-23  02:53:15
# 3  39.984688  116.318385       0  492.0  39744.120370  2008-10-23  02:53:20
# 4  39.984655  116.318263       0  492.0  39744.120428  2008-10-23  02:53:25
# 5  39.984611  116.318026       0  493.0  39744.120486  2008-10-23  02:53:30
# 6  39.984608  116.317761       0  493.0  39744.120544  2008-10-23  02:53:35
#
#   user_id       trajectory_id           timestamp  time_gap   prev_lat  \
# 2     000  20081023025304.plt 2008-10-23 02:53:15       5.0  39.984683
# 3     000  20081023025304.plt 2008-10-23 02:53:20       5.0  39.984686
# 4     000  20081023025304.plt 2008-10-23 02:53:25       5.0  39.984688
# 5     000  20081023025304.plt 2008-10-23 02:53:30       5.0  39.984655
# 6     000  20081023025304.plt 2008-10-23 02:53:35       5.0  39.984611
#
#      prev_lon  distance_delta     speed  prev_speed  acceleration     bearing  \
# 2  116.318450        2.831299  0.566260    0.586148     -0.003978  276.766339
# 3  116.318417        2.735434  0.547087    0.566260     -0.003835  274.663284
# 4  116.318385       11.023008  2.204602    0.547087      0.331503  250.555849
# 5  116.318263       20.776544  4.155309    2.204602      0.390141  256.379828
# 6  116.318026       22.580319  4.516064    4.155309      0.072151  269.153609
#
#    prev_bearing  direction_change
# 2    126.922277        149.844061
# 3    276.766339          2.103055
# 4    274.663284         24.107435
# 5    250.555849          5.823979
# 6    256.379828         12.773781

# %%
import os

BASE_PATH = r"D:\Randome shit\TourX\ml-services"

csv_path = os.path.join(BASE_PATH, "geolife_processed.csv")

print("Saving CSV...")
df.to_csv(csv_path, index=False)


print("All files saved successfully!")
# Out:
# Saving CSV...
# All files saved successfully!

# %%
# import os
# import pyarrow
# BASE_PATH = r"D:\Randome shit\TourX\ml-services"
# parquet_path = os.path.join(BASE_PATH, "geolife_processed.parquet")

# # df.to_parqueta
#     parquet_path,
#     engine="pyarrow",
#     compression="snappy",
#     index=False
# )

# print("Saved in fastest & smallest format (Parquet + Snappy)")

# %%
features = [
    "distance_delta",
    "speed",
    "acceleration",
    "time_gap",
    "direction_change"
]

df_model = df[["user_id", "trajectory_id"] + features].copy()

df_model.head()
# Out:
#   user_id       trajectory_id  distance_delta     speed  acceleration  \
# 2     000  20081023025304.plt        2.831299  0.566260     -0.003978
# 3     000  20081023025304.plt        2.735434  0.547087     -0.003835
# 4     000  20081023025304.plt       11.023008  2.204602      0.331503
# 5     000  20081023025304.plt       20.776544  4.155309      0.390141
# 6     000  20081023025304.plt       22.580319  4.516064      0.072151
#
#    time_gap  direction_change
# 2       5.0        149.844061
# 3       5.0          2.103055
# 4       5.0         24.107435
# 5       5.0          5.823979
# 6       5.0         12.773781

# %%
df = df[df["time_gap"] > 0]

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)
# Out:
#                 lat         lon  unused          alt          date  \
# 2         39.984686  116.318417       0   492.000000  39744.120313
# 3         39.984688  116.318385       0   492.000000  39744.120370
# 4         39.984655  116.318263       0   492.000000  39744.120428
# 5         39.984611  116.318026       0   493.000000  39744.120486
# 6         39.984608  116.317761       0   493.000000  39744.120544
# ...             ...         ...     ...          ...           ...
# 24876973  40.914867  111.710500       0  3802.493438  39521.152731
# 24876974  40.914267  111.710333       0  3795.931759  39521.153669
# 24876975  40.912467  111.710667       0  3795.931759  39521.154884
# 24876976  40.911517  111.711317       0  3779.527559  39521.155185
# 24876977  40.910933  111.711617       0  3802.493438  39521.155324
#
#                date2      time user_id       trajectory_id  \
# 2         2008-10-23  02:53:15     000  20081023025304.plt
# 3         2008-10-23  02:53:20     000  20081023025304.plt
# 4         2008-10-23  02:53:25     000  20081023025304.plt
# 5         2008-10-23  02:53:30     000  20081023025304.plt
# 6         2008-10-23  02:53:35     000  20081023025304.plt
# ...              ...       ...     ...                 ...
# 24876973  2008-03-14  03:39:56     181  20080314025755.plt
# 24876974  2008-03-14  03:41:17     181  20080314025755.plt
# 24876975  2008-03-14  03:43:02     181  20080314025755.plt
# 24876976  2008-03-14  03:43:28     181  20080314025755.plt
# 24876977  2008-03-14  03:43:40     181  20080314025755.plt
#
#                    timestamp  time_gap   prev_lat    prev_lon  distance_delta  \
# 2        2008-10-23 02:53:15       5.0  39.984683  116.318450        2.831299
# 3        2008-10-23 02:53:20       5.0  39.984686  116.318417        2.735434
# 4        2008-10-23 02:53:25       5.0  39.984688  116.318385       11.023008
# 5        2008-10-23 02:53:30       5.0  39.984655  116.318263       20.776544
# 6        2008-10-23 02:53:35       5.0  39.984611  116.318026       22.580319
# ...                      ...       ...        ...         ...             ...
# 24876973 2008-03-14 03:39:56     112.0  40.915433  111.711450      101.698458
# 24876974 2008-03-14 03:41:17      81.0  40.914867  111.710500       68.171002
# 24876975 2008-03-14 03:43:02     105.0  40.914267  111.710333      202.101290
# 24876976 2008-03-14 03:43:28      26.0  40.912467  111.710667      118.921029
# 24876977 2008-03-14 03:43:40      12.0  40.911517  111.711317       69.590492
#
#              speed  prev_speed  acceleration     bearing  prev_bearing  \
# 2         0.566260    0.586148     -0.003978  276.766339    126.922277
# 3         0.547087    0.566260     -0.003835  274.663284    276.766339
# 4         2.204602    0.547087      0.331503  250.555849    274.663284
# 5         4.155309    2.204602      0.390141  256.379828    250.555849
# 6         4.516064    4.155309      0.072151  269.153609    256.379828
# ...            ...         ...           ...         ...           ...
# 24876973  0.908022    0.849449      0.000523  231.714749    234.423756
# 24876974  0.841617    0.908022     -0.000820  191.855062    231.714749
# 24876975  1.924774    0.841617      0.010316  172.033395    191.855062
# 24876976  4.573886    1.924774      0.101889  152.657698    172.033395
# 24876977  5.799208    4.573886      0.102110  158.760855    152.657698
#
#           direction_change
# 2               149.844061
# 3                 2.103055
# 4                24.107435
# 5                 5.823979
# 6                12.773781
# ...                    ...
# 24876973          2.709007
# 24876974         39.859687
# 24876975         19.821667
# 24876976         19.375697
# 24876977          6.103157
#
# [24071047 rows x 20 columns]

# %%
df = df.dropna()

# %%
print("Any inf left:", np.isinf(df[features]).sum().sum())
print("Any NaN left:", df[features].isna().sum().sum())
# Out:
# Any inf left: 0
# Any NaN left: 0

# %%
scaler = MinMaxScaler()

df_model = df[["user_id", "trajectory_id"] + features].copy()
df_model[features] = scaler.fit_transform(df_model[features])

print("Scaling complete")
# Out:
# Scaling complete

# %%
def create_sequences_limited(df, features, seq_len, max_per_traj=2000):
    sequences = []

    grouped = df.groupby(["user_id", "trajectory_id"])

    for _, group in grouped:
        data = group[features].values

        if len(data) < seq_len:
            continue

        count = 0
        for i in range(len(data) - seq_len):
            sequences.append(data[i:i+seq_len])
            count += 1

            if count >= max_per_traj:
                break

    return np.array(sequences)

# %%
SEQ_LEN = 20

X_sequences = create_sequences_limited(
    df_model,
    features,
    SEQ_LEN,
    max_per_traj=1500
)

print("Shape:", X_sequences.shape)
# Out:
# Shape: (12332162, 20, 5)
